# %%
import json

f = open('hash-rate.json')

data = json.load(f)

# %%
data
# Out:
# {'metric1': 'hash-rate',
#  'metric2': 'market-price',
#  'hash-rate': [{'x': 1231545600000, 'y': 1.0652200634920637e-07},
#   {'x': 1231891200000, 'y': 2.521020816931218e-06},
#   {'x': 1232236800000, 'y': 5.58885459978836e-06},
#   {'x': 1232582400000, 'y': 5.681173671957674e-06},
#   {'x': 1232928000000, 'y': 6.270595440423281e-06},
#   {'x': 1233273600000, 'y': 6.4197262493121684e-06},
#   {'x': 1233619200000, 'y': 5.8303044808465595e-06},
#   {'x': 1233964800000, 'y': 6.256392506243385e-06},
#   {'x': 1234310400000, 'y': 6.306102775873014e-06},
#   {'x': 1234656000000, 'y': 6.4126247822222205e-06},
#   {'x': 1235001600000, 'y': 6.178276368253967e-06},
#   {'x': 1235347200000, 'y': 5.972333822645502e-06},
#   {'x': 1235692800000, 'y': 5.539144330158728e-06},
#   {'x': 1236038400000, 'y': 5.318998850370366e-06},
#   {'x': 1236384000000, 'y': 5.31189738328042e-06},
#   {'x': 1236729600000, 'y': 5.475231126349206e-06},
#   {'x': 1237075200000, 'y': 5.581753132698413e-06},
# ...
